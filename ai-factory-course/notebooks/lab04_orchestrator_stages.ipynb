# %% [markdown]
# Lab 04 — Orchestrator stage flow (Module 4).
#
# Walk IDEA_RECEIVED → COMPLETED using pipeline_flow.json.
# Run:  python labs/lab04_orchestrator_stages.py
# Exercise: python labs/run_exercises.py --module m4
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alexar76/aimarket-courses/blob/main/ai-factory-course/notebooks/{})

# %%
# Setup — run this cell once per session
# Core course only — no network hub deps
import os
import subprocess
import sys

REPO = "https://github.com/alexar76/aimarket-courses.git"
DEST = "/content/aimarket-courses"

if not os.path.isdir(DEST):
    subprocess.run(["git", "clone", "-q", "--depth", "1", REPO, DEST], check=True)
WORKDIR = os.path.join(DEST, "ai-factory-course")
os.chdir(WORKDIR)

subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-e", ".[factory,dev]"], check=True)
os.environ.setdefault("COURSE_LANG", "en")  # change to ru or es

# %%
"""Lab 04 — Orchestrator stage flow (Module 4).

Walk IDEA_RECEIVED → COMPLETED using pipeline_flow.json.
Run:  python labs/lab04_orchestrator_stages.py
Exercise: python labs/run_exercises.py --module m4
"""

from __future__ import annotations



from courselib.factory import walk_to_ship
from courselib.i18n import get_translator
from courselib.trace import Trace


def main() -> None:
    t = get_translator()
    trace = Trace()
    print(f"== {t('modules.m4.title')} ==")
    print(t("modules.m4.concept"))

    path = walk_to_ship()
    print(f"\n--- {t('labs.lab04.path_heading')} ({len(path)} steps) ---")
    for step in path[:8]:
        trace.log("transition", state=step["state"], agent=step.get("agent") or "—")
        agent = step.get("agent") or "—"
        print(f"  {step['state']:24} agent={agent}")
    if len(path) > 8:
        print(f"  … +{len(path) - 8} more → {path[-1]['state']}")

    print(f"\n{t('ui.trace')} ({len(trace)} {t('ui.events')}):")
    for event in trace.events:
        print(" ", event)

    print(f"\n--- {t('exercises.heading')} ---")
    print(t("exercises.lab04_hint"))

main()
